# %% [markdown]
# # Repaso: Fundamentos de Programación en Python
#
# ## Preparación para certificación – Análisis de Datos
#
# Este notebook contiene ejercicios de repaso enfocados en:
#
# - `print()` e `input()`
# - Tipos de datos y conversión
# - Operadores aritméticos, relacionales y lógicos
# - Funciones matemáticas
# - Formateo de texto y números
# - Funciones definidas por el usuario
# - Estructuras condicionales
# - Estructuras iterativas
# - Listas
# - Tuplas
# - Diccionarios
# - Desafíos prácticos de programación contextual
#
# La idea es trabajar **problemas de planteamiento** similares a situaciones reales de análisis de datos.
# En cada ejercicio se propone una pregunta; intenta resolverla antes de revisar la solución.

# %% [markdown]
# # 1. `print()` y salida de información
#
# ## Problema 1: Reporte de ventas
#
# Una tienda registró ventas por `$125000`. Completa el código para mostrar:
#
# ```text
# El total de ventas es: $125000
# ```
#
# ### Pregunta
# ¿Cuál de las siguientes alternativas produce una salida correcta?
#
# A)
# ```python
# print("El total de ventas es: $" + 125000)
# ```
#
# B)
# ```python
# print("El total de ventas es: $", 125000)
# ```
#
# C)
# ```python
# print(El total de ventas es: $, 125000)
# ```
#
# D)
# ```python
# print = ("El total de ventas es: $", 125000)
# ```

# %%
# Solución
ventas = 125000
print("El total de ventas es: $", ventas)

# Respuesta correcta: B
# Out:
# El total de ventas es: $ 125000

# %% [markdown]
# ## Problema 2: Interpretación de código
#
# ¿Qué mostrará el siguiente código?
#
# ```python
# nombre = "Ana"
# edad = 28
#
# print(nombre, "tiene", edad, "años")
# ```
#
# A) `Anatiene28años`
# B) `Ana tiene 28 años`
# C) Produce un error
# D) `nombre tiene edad años`

# %%
nombre = "Ana"
edad = 28
print(nombre,"tiene",edad, "años")




# Respuesta: B
# Out:
# Ana tiene 28 años

# %% [markdown]
# # 2. `input()` y conversión de datos
#
# ## Problema 3: Registro de edad
#
# Se desea solicitar la edad de una persona y calcular su edad aproximada el próximo año.
#
# Completa el código:
#
# ```python
# edad = input("Ingrese su edad: ")
# ```
#
# ¿Por qué es necesario convertir `edad` antes de realizar:
#
# ```python
# edad + 1
# ```
#
# A) Porque `input()` siempre devuelve un número.
# B) Porque `input()` devuelve un texto (`str`).
# C) Porque Python no permite sumar.
# D) Porque `1` debe convertirse en texto.

# %%
# Solución
edad = 28  # Simulación de la entrada
proxima_edad = int(edad) + 1
print("El próximo año tendrá", proxima_edad, "años")

# En un programa interactivo:
# edad = int(input("Ingrese su edad: "))

# Respuesta: B
# Out:
# El próximo año tendrá 29 años

# %% [markdown]
# ## Problema 4: Ingreso de ventas
#
# Una analista solicita el monto de ventas del día y desea agregar un 10% de comisión.
#
# ¿Qué conversión es más adecuada?
#
# A) `str()`
# B) `int()` siempre
# C) `float()`
# D) `bool()`

# %%
# Solución
venta = 125000.50
comision = venta * 0.10
print("Comisión:", comision)

# Respuesta: C, especialmente cuando el monto puede contener decimales.
# Out:
# Comisión: 12500.050000000001

# %% [markdown]
# # 3. Tipos de datos
#
# ## Problema 5: Clasificación de variables en Python
#
# Considera:
#
# ```python
# nombre = "Carlos"
# edad = 35
# altura = 1.75
# activo = True
# ```
#
# Relaciona cada variable con su tipo de dato:
#
# - `nombre`
# - `edad`
# - `altura`
# - `activo`
#
# Tipos posibles:
#
# - `str`
# - `int`
# - `float`
# - `bool`

# %%
nombre = "Carlos"
edad = 35
altura = 1.75
activo = True

print(type(nombre))
print(type(edad))
print(type(altura))
print(type(activo))

# nombre -> str
# edad -> int
# altura -> float
# activo -> bool
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Problema 6: Conversión
#
# Una base de datos entrega la cantidad de clientes como texto:
#
# ```python
# clientes = "150"
# ```
#
# ¿Qué resultado produce?
#
# ```python
# clientes * 2
# ```
#
# A) `300`
# B) `"150150"`
# C) Error
# D) `1502`
#
# ¿Qué debes hacer para obtener el resultado numérico `300`?

# %%
clientes = "150"

print(clientes * 3)        # Repite el texto
print(int(clientes) * 2)   # Operación numérica
# Out:
# 150150150
# 300

# %% [markdown]
# # 4. Operadores aritméticos, relacionales y lógicos
#
# ## Problema 7: ¿La meta fue cumplida?
#
# Una empresa considera que una sucursal cumple su meta cuando sus ventas son mayores o iguales a `500000`.
#
# ```python
# ventas = 620000
# ```
#
# Completa una expresión que devuelva `True` o `False`.

# %%
ventas = 620000
meta_cumplida = ventas >= 500000

print(meta_cumplida)
# Out:
# True

# %% [markdown]
# ## Problema 8: Condición compuesta
#
# Un cliente recibe un descuento si:
#
# - es cliente frecuente **y**
# - su compra es superior a `$100000`.
#
# ¿Cuál operador lógico corresponde?
#
# A) `or`
# B) `and`
# C) `not`
# D) `in`

# %%
cliente_frecuente = True
compra = 120000

descuento = cliente_frecuente and compra > 100000
print(descuento)

# Respuesta: B
# Out:
# True

# %% [markdown]
# # 5. Funciones matemáticas
#
# ## Problema 9: Cálculo de raíz y redondeo
#
# Se registró una distancia al cuadrado de:
#
# ```python
# distancia_cuadrada = 225
# ```
#
# 1. Calcula la raíz cuadrada.
# 2. Redondea el resultado de `12.6789` a 2 decimales.
#
# Investiga o utiliza funciones matemáticas apropiadas.

# %%
import math

distancia_cuadrada = 225
distancia = math.sqrt(distancia_cuadrada)

valor = 12.6789
valor_redondeado = round(valor,2)

print(distancia)
print(valor_redondeado)
# Out:
# 15.0
# 12.68

# %% [markdown]
# ## Problema 10: Valor absoluto
#
# Una empresa esperaba vender `1000` unidades, pero vendió `850`.
#
# Queremos medir la diferencia sin importar si fue positiva o negativa.
#
# ¿Qué función puede utilizarse?
#
# A) `abs()`
# B) `round()`
# C) `sum()`
# D) `len()`

# %%
esperado = 1000
real = 850

diferencia = abs(real - esperado)
print(diferencia)

# Respuesta: A
# Out:
# 150

# %% [markdown]
# # 6. Formateo de texto y números
#
# ## Problema 11: Reporte formateado
#
# Una empresa desea mostrar:
#
# ```text
# Producto: Notebook | Precio: $599990.50
# ```
#
# Utiliza una **f-string**.

# %%
producto = "Notebook"
precio = 599990.5

print(f"Producto: {producto} | Precio: ${precio:.2f}")
# Out:
# Producto: Notebook | Precio: $599990.50

# %% [markdown]
# ## Problema 12: Porcentajes
#
# La tasa de aprobación fue:
#
# ```python
# tasa = 0.8735
# ```
#
# ¿Cómo mostrarías el resultado como:
#
# ```text
# 87.35%
# ```

# %%
tasa = 0.8735
print(f"Tasa de aprobación: {tasa:.2%}")
# Out:
# Tasa de aprobación: 87.35%

# %% [markdown]
# # 7. Funciones
#
# ## Problema 13: Crear una función
#
# Una tienda necesita calcular el IVA de cualquier monto.
#
# Crea una función llamada `calcular_iva(monto)` que devuelva el 19% del monto.

# %%
def calcular_iva(monto):
    return monto * 0.19

precio = 100000
iva = calcular_iva(precio)

print(f"IVA: ${iva:,.0f}")
# Out:
# IVA: $19,000

# %% [markdown]
# ## Problema 14: Parámetros y retorno
#
# ¿Qué diferencia principal existe entre:
#
# ```python
# def saludar(nombre):
#     print(f"Hola {nombre}")
# ```
#
# y
#
# ```python
# def cuadrado(numero):
#     return numero ** 2
# ```
#
# ### Discusión
# - ¿Qué hace `print()`?
# - ¿Qué hace `return`?
# - ¿Cuál función permite reutilizar directamente su resultado en otro cálculo?

# %%
def saludar(nombre):
    print(f"Hola {nombre}")

def cuadrado(numero):
    return numero ** 2

saludar("Ana")
resultado = cuadrado(5)
print(resultado)
# Out:
# Hola Ana
# 25

# %% [markdown]
# ## Problema 15: Función para clasificar ventas
#
# Crea una función que reciba un monto y devuelva:
#
# - `"Alta"` si la venta es mayor o igual a 500000.
# - `"Media"` si está entre 200000 y 499999.
# - `"Baja"` si es menor a 200000.

# %%
def clasificar_venta(monto):
    if monto >= 500000:
        return "Alta"
    elif monto >= 200000:
        return "Media"
    else:
        return "Baja"

print(clasificar_venta(50000))
print(clasificar_venta(350000))
print(clasificar_venta(90000))
# Out:
# Baja
# Media
# Baja

# %% [markdown]
# # 8. Estructuras condicionales
#
# ## Problema 16: Aprobación de un curso
#
# Una persona aprueba si su nota es mayor o igual a 4.0.
#
# Además:
#
# - Nota ≥ 6.0 → `"Excelente"`
# - Nota entre 4.0 y 5.9 → `"Aprobado"`
# - Nota < 4.0 → `"Reprobado"`
#
# Construye la estructura `if / elif / else`.

# %%
nota = 5.5

if nota >= 6.0:
    resultado = "Excelente"
elif nota >= 4.0:
    resultado = "Aprobado"
else:
    resultado = "Reprobado"

print(resultado)
# Out:
# Aprobado

# %% [markdown]
# ## Problema 17: Error frecuente
#
# ¿Qué ocurre si escribimos?
#
# ```python
# if edad >= 18:
# print("Mayor de edad")
# ```
#
# A) Funciona normalmente.
# B) Produce un error por indentación.
# C) Siempre imprime el mensaje.
# D) Convierte `edad` en entero.
#
# **Respuesta esperada: B.**

# %%
edad = 20

if edad >= 18:
  print("Mayor de edad")
else:
  print("Menor de edad")
# Out:
# Mayor de edad

# %% [markdown]
# # 9. Estructuras iterativas
#
# ## Problema 18: Recorrer ventas
#
# Una empresa tiene las siguientes ventas diarias:
#
# ```python
# ventas = [120, 150, 180, 90, 200]
# ```
#
# Utiliza un ciclo `for` para imprimir cada venta.

# %%
ventas = [120, 150, 180, 90, 200]

for venta in ventas:
    print(venta)
# Out:
# 120
# 150
# 180
# 90
# 200

# %% [markdown]
# ## Problema 19: Sumar valores con un ciclo
#
# Sin utilizar inicialmente `sum()`, calcula el total de:
#
# ```python
# ventas = [120, 150, 180, 90, 200]
# ```

# %%
ventas = [120, 150, 180, 90, 200]

total = 0

for venta in ventas:
    total = total + venta

print("Total:", total)
# Out:
# Total: 740

# %% [markdown]
# ## Problema 20: `while`
#
# Una empresa desea contar cuántos meses necesita para alcanzar un ahorro de `$1000000`.
#
# Supongamos que comienza con `$0` y ahorra `$250000` mensuales.
#
# Utiliza un ciclo `while`.

# %%
ahorro = 0
meta = 1000000
meses = 0

while ahorro < meta:
    ahorro += 250000
    meses += 1

print(f"Meses necesarios: {meses}")
# Out:
# Meses necesarios: 4

# %% [markdown]
# # 10. Listas
#
# ## Problema 21: Operaciones básicas
#
# Considera:
#
# ```python
# productos = ["Notebook", "Mouse", "Teclado"]
# ```
#
# Realiza las siguientes tareas:
#
# 1. Obtén el primer elemento.
# 2. Agrega `"Monitor"`.
# 3. Elimina `"Mouse"`.
# 4. Determina la cantidad de productos.

# %%
productos = ["Notebook", "Mouse", "Teclado"]

print("Primer producto:", productos[0])

productos.append("Monitor")
productos.remove("Mouse")

print(productos)
print("Cantidad:", len(productos))
# Out:
# Primer producto: Notebook
# ['Notebook', 'Teclado', 'Monitor']
# Cantidad: 3

# %% [markdown]
# ## Problema 22: Indexación
#
# ¿Cuál es el resultado?
#
# ```python
# numeros = [10, 20, 30, 40]
# print(numeros[-2])
# ```
#
# A) 10
# B) 20
# C) 30
# D) 40

# %%
numeros = [10, 20, 30, 40]
print(numeros[-2])

# Respuesta: C
# Out:
# 30

# %% [markdown]
# # 11. Tuplas
#
# ## Problema 23: Información que no debería modificarse
#
# Una empresa registra las coordenadas de una sucursal:
#
# ```python
# ubicacion = (-33.0472, -71.6127)
# ```
#
# ¿Por qué una tupla podría ser apropiada?
#
# A) Porque permite modificar cualquier elemento fácilmente.
# B) Porque es una colección ordenada e inmutable.
# C) Porque solo puede contener números.
# D) Porque funciona únicamente con dos elementos.
#
# **Respuesta esperada: B.**

# %%
ubicacion = (-33.0472, -71.6127)

latitud = ubicacion[0]
longitud = ubicacion[1]

print(latitud, longitud)
# Out:
# -33.0472 -71.6127

# %% [markdown]
# # 12. Diccionarios
#
# ## Problema 24: Ficha de un cliente
#
# Representa la siguiente información mediante un diccionario:
#
# - Nombre: Ana
# - Edad: 32
# - Ciudad: Valparaíso
#
# Luego:
#
# 1. Obtén la ciudad.
# 2. Agrega el campo `activo` con valor `True`.
# 3. Modifica la edad a `33`.

# %%
cliente = {
    "nombre": "Ana",
    "edad": 32,
    "ciudad": "Valparaíso"
}

print(cliente["ciudad"])

cliente["activo"] = True
cliente["edad"] = 33

print(cliente)
# Out:
# Valparaíso
# {'nombre': 'Ana', 'edad': 33, 'ciudad': 'Valparaíso', 'activo': True}

# %% [markdown]
# ## Problema 25: Recorrer un diccionario
#
# Dado:
#
# ```python
# ventas_region = {
#     "Norte": 120000,
#     "Centro": 250000,
#     "Sur": 180000
# }
# ```
#
# Utiliza un ciclo para mostrar:
#
# ```text
# Norte: 120000
# Centro: 250000
# Sur: 180000
# ```

# %%
ventas_region = {
    "Norte": 120000,
    "Centro": 250000,
    "Sur": 180000
}

for region, venta in ventas_region.items():
    print(f"{region}: {venta}")
# Out:
# Norte: 120000
# Centro: 250000
# Sur: 180000

# %% [markdown]
# # 13 — Estadísticos descriptivos con NumPy
#
# Una empresa registra las ventas diarias de un vendedor durante 10 días:
#
# ```python
# import numpy as np
# ventas = np.array([120, 150, 135, 180, 210, 160, 145, 190, 175, 220])
# ```
#
#
# Desarrolle las siguientes tareas utilizando NumPy:
#
# 1. Calcule el promedio de ventas.
# 2. Calcule la mediana.
# 3. Calcule la desviación estándar.
# 4. Determine el valor máximo y mínimo.
# 5. Identifique qué días presentan ventas superiores al promedio.

# %% [markdown]
# # 14. Desafíos prácticos: crear código a partir de un contexto
#
# En esta sección deberás **crear el código**, no solo seleccionar una alternativa.
#
# Cada problema presenta una situación similar a las que pueden aparecer en una tarea de programación o análisis de datos. Lee cuidadosamente:
#
# - **Contexto:** situación que debes resolver.
# - **Entrada:** datos que recibe el programa o la función.
# - **Proceso:** qué debe calcular o decidir.
# - **Salida:** qué debe devolver o mostrar.
# - **Ejemplos:** casos para comprobar tu solución.
#
# > **Recomendación:** intenta resolver cada desafío antes de mirar la solución. En los ejercicios con funciones, respeta exactamente el **nombre de la función, los parámetros y el tipo de resultado solicitado**, porque una evaluación automática puede utilizarlos para comprobar tu código.

# %% [markdown]
# ## Desafío 1: Convertir temperaturas
#
# Una aplicación meteorológica necesita convertir temperaturas entre Celsius y Fahrenheit.
#
# Implementa una función en Python llamada `convertir_temperatura` que reciba dos parámetros:
#
# - `valor` (`float`): temperatura a convertir.
# - `tipo` (`str`): tipo de conversión. Puede ser `"C_F"` (Celsius a Fahrenheit) o `"F_C"` (Fahrenheit a Celsius).
#
# La función debe devolver la temperatura convertida, **redondeada a 2 decimales**.
#
# ### Fórmulas
#
# - Celsius → Fahrenheit: `F = C * 9/5 + 32`
# - Fahrenheit → Celsius: `C = (F - 32) * 5/9`
#
# ### Ejemplos esperados
#
# ```text
# convertir_temperatura(0, "C_F") → 32.0
# convertir_temperatura(100, "C_F") → 212.0
# convertir_temperatura(32, "F_C") → 0.0
# convertir_temperatura(212, "F_C") → 100.0
# ```
#
# **Tarea:** crea la función.

# %%
def convertir_temperatura(valor, tipo):
    # Completa tu código aquí
    pass

# %% [markdown]
# ## Desafío 2: Calcular el precio final de un producto
#
# Una tienda necesita calcular el precio que pagará un cliente después de aplicar un descuento.
#
# Crea una función llamada `precio_final` que reciba:
#
# - `precio` (`float`): precio original.
# - `descuento` (`float`): porcentaje de descuento, por ejemplo `15` significa 15%.
#
# La función debe devolver el precio final **redondeado a 2 decimales**.
#
# ### Ejemplos
#
# ```text
# precio_final(100000, 10) → 90000.0
# precio_final(59990, 15) → 50991.5
# ```
#
# **Tarea:** crea la función utilizando operaciones aritméticas y `round()`.

# %%
def precio_final(precio, descuento):
    # Completa tu código aquí
    pass

# %% [markdown]
# ## Desafío 3: Clasificar el rendimiento de un estudiante
#
# Un sistema académico debe clasificar a un estudiante según su nota final.
#
# Crea una función llamada `clasificar_nota` que reciba una nota (`float`) y devuelva:
#
# - `"Excelente"` si la nota es mayor o igual a `6.0`.
# - `"Aprobado"` si la nota es mayor o igual a `4.0` y menor que `6.0`.
# - `"Reprobado"` si la nota es menor que `4.0`.
#
# ### Ejemplos
#
# ```text
# clasificar_nota(6.5) → "Excelente"
# clasificar_nota(5.2) → "Aprobado"
# clasificar_nota(3.8) → "Reprobado"
# ```
#
# **Tarea:** utiliza `if`, `elif` y `else`.

# %%
def clasificar_nota(nota):
    # Completa tu código aquí
    pass

# %% [markdown]
# ## Desafío 4: Determinar si una persona puede acceder a un beneficio
#
# Una institución entrega un beneficio cuando una persona cumple **ambas** condiciones:
#
# 1. Tiene 60 años o más.
# 2. Está inscrita en el programa.
#
# Crea una función llamada `puede_acceder` que reciba:
#
# - `edad` (`int`)
# - `inscrita` (`bool`)
#
# La función debe devolver `True` si cumple ambas condiciones y `False` en caso contrario.
#
# ### Ejemplos
#
# ```text
# puede_acceder(65, True) → True
# puede_acceder(65, False) → False
# puede_acceder(55, True) → False
# ```
#
# **Tarea:** utiliza operadores relacionales y el operador lógico `and`.

# %%
def puede_acceder(edad, inscrita):
    # Completa tu código aquí
    pass

# %% [markdown]
# ## Desafío 5: Analizar una lista de ventas
#
# Una empresa registra las ventas de cinco días:
#
# ```python
# ventas = [120000, 150000, 180000, 90000, 200000]
# ```
#
# Crea una función llamada `total_ventas` que reciba una lista de ventas y devuelva el total.
#
# **Restricción:** para practicar ciclos, **no utilices `sum()`**. Utiliza un ciclo `for`.
#
# ### Ejemplo
#
# ```text
# total_ventas([120, 150, 180]) → 450
# ```
#
# **Tarea:** crea la función y pruébala con la lista entregada.

# %%
def total_ventas(ventas):
    # Completa tu código aquí
    pass

ventas = [120000, 150000, 180000, 90000, 200000]
# Prueba tu función aquí

# %% [markdown]
# ## Desafío 6: Contar registros que cumplen una condición
#
# Un analista tiene las edades de un grupo de participantes:
#
# ```python
# edades = [17, 21, 35, 16, 42, 19, 15, 28]
# ```
#
# Crea una función llamada `contar_mayores` que reciba una lista de edades y devuelva cuántas personas tienen **18 años o más**.
#
# ### Ejemplo
#
# ```text
# contar_mayores([17, 18, 20, 15]) → 2
# ```
#
# **Tarea:** utiliza un ciclo `for` y una condición `if`.

# %%
def contar_mayores(edades):
    # Completa tu código aquí
    pass

edades = [17, 21, 35, 16, 42, 19, 15, 28]
# Prueba tu función aquí

# %% [markdown]
# ## Desafío 7: Trabajar con una lista de productos
#
# Una tienda tiene:
#
# ```python
# productos = ["Notebook", "Mouse", "Teclado"]
# ```
#
# Crea una función llamada `actualizar_productos` que:
#
# 1. Agregue `"Monitor"` a la lista.
# 2. Elimine `"Mouse"`.
# 3. Devuelva la lista actualizada.
#
# ### Resultado esperado
#
# ```text
# ["Notebook", "Teclado", "Monitor"]
# ```
#
# **Tarea:** utiliza métodos de listas como `append()` y `remove()`.

# %%
def actualizar_productos(productos):
    # Completa tu código aquí
    pass

productos = ["Notebook", "Mouse", "Teclado"]
# Prueba tu función aquí

# %% [markdown]
# ## Desafío 8: Consultar información de un diccionario
#
# Un sistema almacena información de un estudiante:
#
# ```python
# estudiante = {
#     "nombre": "Ana",
#     "edad": 22,
#     "carrera": "Ingeniería",
#     "promedio": 5.8
# }
# ```
#
# Crea una función llamada `resumen_estudiante` que reciba el diccionario y devuelva un texto con el siguiente formato:
#
# ```text
# Ana - Ingeniería - Promedio: 5.8
# ```
#
# **Tarea:** accede a los valores mediante sus claves y utiliza una f-string.

# %%
def resumen_estudiante(estudiante):
    # Completa tu código aquí
    pass

estudiante = {
    "nombre": "Ana",
    "edad": 22,
    "carrera": "Ingeniería",
    "promedio": 5.8
}

# Prueba tu función aquí

# %% [markdown]
# ## Desafío 9: Calcular un promedio
#
# Un profesor registra las notas de una evaluación:
#
# ```python
# notas = [5.5, 6.0, 4.5, 3.8, 6.2]
# ```
#
# Crea una función llamada `calcular_promedio` que reciba una lista de notas y devuelva el promedio **redondeado a 2 decimales**.
#
# Puedes utilizar `sum()` y `len()`.
#
# ### Ejemplo
#
# ```text
# calcular_promedio([5, 6, 4]) → 5.0
# ```
#
# **Tarea:** crea la función y pruébala con las notas entregadas.

# %%
def calcular_promedio(notas):
    # Completa tu código aquí
    pass

notas = [5.5, 6.0, 4.5, 3.8, 6.2]
# Prueba tu función aquí

# %% [markdown]
# ## Desafío 10: Mini problema integrador — reporte de ventas
#
# Una empresa quiere automatizar un pequeño reporte de ventas.
#
# Se dispone de:
#
# ```python
# ventas = [450000, 620000, 180000, 510000, 300000]
# ```
#
# Crea una función llamada `analizar_ventas` que reciba esta lista y devuelva un diccionario con:
#
# - `"total"`: suma de todas las ventas.
# - `"promedio"`: promedio de las ventas, redondeado a 2 decimales.
# - `"mayores_meta"`: cantidad de ventas mayores o iguales a `500000`.
#
# ### Resultado esperado para los datos entregados
#
# ```python
# {
#     "total": 2060000,
#     "promedio": 412000.0,
#     "mayores_meta": 2
# }
# ```
#
# **Tarea:** resuelve el problema utilizando funciones, listas, ciclo `for`, condiciones y diccionarios.

# %%
def analizar_ventas(ventas):
    # Completa tu código aquí
    pass

ventas = [450000, 620000, 180000, 510000, 300000]
# Prueba tu función aquí

# %% [markdown]
# ### Solución Desafío 1

# %%
def convertir_temperatura(valor, tipo):
    if tipo == "C_F":
        resultado = valor * 9/5 + 32
    elif tipo == "F_C":
        resultado = (valor - 32) * 5/9
    else:
        raise ValueError("Tipo de conversión no válido")
    return round(resultado, 2)

# %% [markdown]
# ### Solución Desafío 2

# %%
def precio_final(precio, descuento):
    resultado = precio - (precio * descuento / 100)
    return round(resultado, 2)

# %% [markdown]
# ### Solución Desafío 3

# %%
def clasificar_nota(nota):
    if nota >= 6.0:
        return "Excelente"
    elif nota >= 4.0:
        return "Aprobado"
    else:
        return "Reprobado"

# %% [markdown]
# ### Solución Desafío 4

# %%
def puede_acceder(edad, inscrita):
    return edad >= 60 and inscrita

# %% [markdown]
# ### Solución Desafío 5

# %%
def total_ventas(ventas):
    total = 0
    for venta in ventas:
        total += venta
    return total

# %% [markdown]
# ### Solución Desafío 6

# %%
def contar_mayores(edades):
    cantidad = 0
    for edad in edades:
        if edad >= 18:
            cantidad += 1
    return cantidad

# %% [markdown]
# ### Solución Desafío 7

# %%
def actualizar_productos(productos):
    productos.append("Monitor")
    productos.remove("Mouse")
    return productos

# %% [markdown]
# ### Solución Desafío 8

# %%
def resumen_estudiante(estudiante):
    return f"{estudiante['nombre']} - {estudiante['carrera']} - Promedio: {estudiante['promedio']}"

# %% [markdown]
# ### Solución Desafío 9

# %%
def calcular_promedio(notas):
    return round(sum(notas) / len(notas), 2)

# %% [markdown]
# ### Solución Desafío 10

# %%
def analizar_ventas(ventas):
    total = sum(ventas)
    promedio = round(total / len(ventas), 2)

    mayores_meta = 0
    for venta in ventas:
        if venta >= 500000:
            mayores_meta += 1

    return {
        "total": total,
        "promedio": promedio,
        "mayores_meta": mayores_meta
    }

# %% [markdown]
# # 13. Mini simulación
#
# ## Pregunta 1
#
# ¿Qué tipo de dato devuelve `input()`?
#
# A) `int`
# B) `float`
# C) `str`
# D) `bool`
#
# ## Pregunta 2
#
# ¿Cuál función permite conocer la cantidad de elementos de una lista?
#
# A) `count()`
# B) `len()`
# C) `sum()`
# D) `type()`
#
# ## Pregunta 3
#
# ¿Qué imprime?
#
# ```python
# x = [1, 2, 3]
# x.append(4)
# print(len(x))
# ```
#
# A) 3
# B) 4
# C) `[1, 2, 3]`
# D) Error
#
# ## Pregunta 4
#
# ¿Cuál estructura permite repetir instrucciones mientras una condición sea verdadera?
#
# A) `if`
# B) `for`
# C) `while`
# D) `def`
#
# ## Pregunta 5
#
# ¿Qué función devuelve el valor absoluto?
#
# A) `abs()`
# B) `round()`
# C) `sqrt()`
# D) `len()`
#
# ## Pregunta 6
#
# ¿Cuál es una característica principal de una tupla?
#
# A) Es mutable.
# B) Es inmutable.
# C) Solo contiene texto.
# D) No puede recorrerse.
#
# ## Pregunta 7
#
# ¿Cuál es la forma correcta de obtener el valor asociado a `"nombre"`?
#
# ```python
# persona = {"nombre": "Ana"}
# ```
#
# A) `persona.nombre`
# B) `persona("nombre")`
# C) `persona["nombre"]`
# D) `persona[0]`
#
# ## Pregunta 8
#
# ¿Qué operador lógico exige que ambas condiciones sean verdaderas?
#
# A) `or`
# B) `and`
# C) `not`
# D) `in`

# %% [markdown]
# ## Respuestas mini simulación
#
# 1. C
# 2. B
# 3. B
# 4. C
# 5. A
# 6. B
# 7. C
# 8. B
#
# ---
#
# # Checklist final
#
# Antes de la certificación deberías poder:
#
# - [ ] Diferenciar `print()` e `input()`.
# - [ ] Identificar y convertir tipos de datos.
# - [ ] Usar operadores aritméticos, relacionales y lógicos.
# - [ ] Utilizar funciones como `len()`, `sum()`, `round()` y `abs()`.
# - [ ] Importar y utilizar funciones matemáticas básicas.
# - [ ] Formatear textos y números con f-strings.
# - [ ] Crear funciones con parámetros y `return`.
# - [ ] Construir estructuras `if`, `elif` y `else`.
# - [ ] Utilizar ciclos `for` y `while`.
# - [ ] Crear y manipular listas.
# - [ ] Comprender cuándo utilizar tuplas.
# - [ ] Crear, modificar y recorrer diccionarios.
# - [ ] Integrar varios conceptos para resolver un problema sencillo.
