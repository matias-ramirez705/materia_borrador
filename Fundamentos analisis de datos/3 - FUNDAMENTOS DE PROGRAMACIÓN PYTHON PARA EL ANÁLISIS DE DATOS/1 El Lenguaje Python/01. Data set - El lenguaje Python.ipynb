# %% [markdown]
# # Unidad 1 — El lenguaje Python

# %% [markdown]
# ## Visual Studio Code — Entorno de Desarrollo Integrado (IDE)
# **Slide 13 — Verificación de la instalación**

# %%
python --version

# %% [markdown]
# **Slide 16 — Escribe tu primer programa (`hola_mundo.py`)**

# %%
print("¡Hola, mundo!")

# %% [markdown]
# ---
# ## El editor Spyder — Ejercicio
# **Slide 31 — En el editor, escribe (`mi_primer_script.py`)**

# %%
print("¡Hola, Spyder!")
print("Este es mi primer script en Python.")

# %% [markdown]
# ---
# ## Jupyter notebooks — Cómo abrir un nuevo notebook
# **Slide 27 — En la primera celda, escribe:**

# %%
print("¡Hola, mundo!")

# %% [markdown]
# **Slide 28 — En la siguiente celda, escribe:**

# %%
2 + 2

# %% [markdown]
# ---
# ## Google Colab — Acceder y crear un nuevo notebook en Colab
# **Slide 35 — En la primera celda, escribe y ejecuta:**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un DataFrame simple
df = pd.DataFrame({'x': range(10), 'y': [i**2 for i in range(10)]})

# Crear un gráfico
plt.plot(df['x'], df['y'])
plt.title('Gráfico de y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
