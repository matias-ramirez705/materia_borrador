# %% [markdown]
# # Unidad 2 — Secuencias básicas del lenguaje Python

# %% [markdown]
# ---
# ## Impresión en consola — ¿Cómo mostramos información? (print)
# **Slide 6**

# %%
# Mostrando un mensaje simple
print("¡Hola! Bienvenido a Python")

# Mostrando varios elementos
print("El resultado es:", 42)

# Mostrando en múltiples líneas
print("Primera línea")
print("Segunda línea")

# %% [markdown]
# ---
# ## Entrada de datos en consola — ¿Cómo recibimos información? (input)
# **Slide 7**

# %%
# Preguntando al usuario
respuesta = input("¿Cómo te llamas? ")
print("¡Hola,", respuesta, "!")

# %% [markdown]
# ---
# ## ¡Manos a la obra! Primer diálogo
# **Slide 9 — Abre tu editor y crea un archivo `dialogo.py`. Escribe este código:**

# %%
# Saludamos al usuario
print("¡Hola! Vamos a conocernos")

# Hacemos algunas preguntas
nombre = input("¿Cómo te llamas? ")
color = input("¿Cuál es tu color favorito? ")

# Respondemos usando la información
print("¡Mucho gusto,", nombre, "!")
print("El", color, "es un color muy bonito")

# %% [markdown]
# ---
# ## Tipos de datos de una variable
# **Slide 14**

# %%
entero = 2
decimal = -6.5
texto = "Hola Mundo"

print(type(entero))   # int
print(type(decimal))  # float
print(type(texto))    # str

# %% [markdown]
# ---
# ## Manipulando variables
# **Slide 16**

# %%
a = 2  # se asigna el valor 2 a la variable a
a = a + 1  # se suma 1 al valor de a y se reasigna
print(a)  # se muestra el resultado final

# %%
nombre = "Carlos"
# se asigna el valor Carlos a la variable nombre
apellido = "Santana"
# se asigna el valor Santana a la variable apellido

print(nombre + " " + apellido)
# se muestra el resultado final

# %% [markdown]
# ---
# ## Transformando los datos — Interpolación y Precisión de datos
# **Slide 17**

# %%
nombre = 'Carlos'
apellido = 'Santana'
# Interpolación
print("Mi nombre es {} {}".format(nombre, apellido))

# %%
nombre = 'Carlos'
apellido = 'Santana'
# Interpolación
print(f"Mi nombre es {nombre} {apellido}")

# %%
# Operación que arroja varios decimales
print(f'El resultado es {1/9}')

# Muestro sólo 2 decimales
print(f'El resultado es {1/9:.2f}')

# %% [markdown]
# ---
# ## Valores numéricos — Integer y Floats
# **Slide 20**

# %%
# estos son valores integer
print(27)
print(-5)
print(0)
print(3 + 7)
print(31 - 7)
print(4 * 8)

# %%
# estos son valores float
print(27.6)
print(-5.9)
print(0.0)
print(3.2 + 7.456)
print(31.5 - 7.0)
print(4.190 * 8.12)
print(9.0 / 8.1)

# %% [markdown]
# ---
# ## Strings — Concatenación y Duplicación
# **Slide 24**

# %%
# Concatenación
print("Carlos" + "Santana")   # CarlosSantana
print("Carlos " + "Santana")  # Carlos Santana

# Concatenación
print("15" + "23")  # esto resulta en 1523

# %%
# Duplicación
print(3 * "Carlos")  # CarlosCarlosCarlos
print(5 * "12")      # 1212121212

# %% [markdown]
# ---
# ## ¡Manos a la obra! Presentándome con Python — Ejercicio guiado
# **Slides 29–30 — Crear archivo `presentador.py`**

# %%
nombre = input('Ingrese su Nombre: ')
edad = input('Ingrese Edad: ')
ocupacion = input('Ingrese Ocupación: ')
lugar = input('En dónde?: ')
caracteristica_1 = input('Ingrese 3 características:\n1. > ')
caracteristica_2 = input('2. > ')
caracteristica_3 = input('3. > ')
pasatiempo = input('Cuál es tu pasatiempo: ')
hacer = input('¿Que quieres hacer? ')

# %%
print(f'''
Mi nombre es {nombre}, tengo {edad} años y me desempeño como {ocupacion} en {lugar}.
Soy una persona {caracteristica_1}, {caracteristica_2} y {caracteristica_3}.

Mi pasatiempo es {pasatiempo} y me gustaría poder {hacer}.''')

# %% [markdown]
# ---
# ## ¡Manos a la obra! Calculadora de descuentos — Ejercicio guiado
# **Slides 36–39 — Crear archivo `calculadora_descuento.py`**

# %%
# Paso 2: Definir las variables
precio_original = input("Ingrese el precio del producto: $")
descuento = input("Ingrese el porcentaje de descuento (sin el %): ")

# Probar ejecutar y mostrar que recibimos los datos
print("Precio ingresado:", precio_original)
print("Descuento ingresado:", descuento)

# %%
# Paso 3: Convertir los datos
precio = float(precio_original)   # Convertimos a decimal
porcentaje = float(descuento)     # Convertimos a decimal

# Mostrar el tipo de datos antes y después
print("Tipo de precio_original:", type(precio_original))
print("Tipo de precio:", type(precio))

# %%
# Paso 4: Realizar los cálculos
# Cálculos
valor_descuento = precio * (porcentaje / 100)
precio_final = precio - valor_descuento
iva = precio_final * 0.19
total_con_iva = precio_final + iva

# %%
# Paso 5: Formatear la salida de datos
print(f"\n=== Resumen de la compra ===")
print(f"Precio original: ${precio:.2f}")
print(f"Descuento ({porcentaje}%): ${valor_descuento:.2f}")
print(f"Precio con descuento: ${precio_final:.2f}")
print(f"IVA (19%): ${iva:.2f}")
print(f"Total a pagar: ${total_con_iva:.2f}")

# %% [markdown]
# ---
# ## Conversiones de tipo
# **Slide 41**

# %%
edad = int("25")
altura = float("1.75")
texto = str(42)
