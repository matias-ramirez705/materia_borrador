# %% [markdown]
# # Opciones de conexión a fuentes de datos en Power BI
# ## Clase 5 - Fundamentos de BI y Obtención de Datos
#
# Esta notebook acompaña la clase sobre conexión a diversas fuentes de datos en Power BI, cubriendo:
# - Archivos de texto plano (CSV, JSON, XML, TXT)
# - Planillas Excel (estructuradas y no estructuradas)
# - Bases de datos (relacionales y no relacionales)
# - Scripts de Python para transformación avanzada
# - Otras fuentes (Cloud, APIs, carpetas compartidas)
#
# **Nota**: Este notebook es una guía conceptual y de preparación. Las conexiones reales a Power BI requieren la herramienta instalada.

# %% [markdown]
# # PARTE 1: Archivos de texto plano (CSV, JSON, XML, TXT)
#
# ## Slide 5-10: Archivos CSV, JSON, XML

# %% [markdown]
# ### Trabajar con CSV en Python (previo a Power BI)

# %%
import pandas as pd
import json
import xml.etree.ElementTree as ET

# ── Slide 5-6: Lectura de CSV
# Simular carga de archivo CSV

# Crear un DataFrame de ejemplo que simule ventas_regionales.csv
csv_data = {
    'Región': ['Norte', 'Sur', 'Este', 'Oeste', 'Centro'],
    'Mes': ['Enero', 'Enero', 'Enero', 'Enero', 'Enero'],
    'Ventas': [15000, 12500, 18000, 11000, 16500],
    'Unidades': [150, 125, 180, 110, 165]
}

df_csv = pd.DataFrame(csv_data)

print("=" * 80)
print("ARCHIVO CSV - Estructura esperada en Power BI")
print("=" * 80)
print(df_csv)
print(f"\nDimensiones: {df_csv.shape[0]} filas × {df_csv.shape[1]} columnas")
print(f"Tipos de datos:\n{df_csv.dtypes}")

# %% [markdown]
# ### Consideraciones al cargar CSV en Power BI:
#
# **Transformaciones comunes (Slide 8):**
# - Promover la primera fila como encabezado
# - Verificar delimitador (coma, punto y coma, tabulación)
# - Detectar correctamente tipos de datos
# - Eliminar columnas vacías
# - Detectar codificación correcta (UTF-8, ANSI)

# %%
# Ejemplos de errores comunes en CSV y cómo prevenirlos

print("\n" + "=" * 80)
print("BUENAS PRÁCTICAS PARA ARCHIVOS CSV (Slide 10)")
print("=" * 80)

prácticas = [
    "1. Establecer una carpeta controlada para carga de archivos periódicos",
    "2. Solicitar estructura fija a los proveedores/exportadores",
    "3. Validar codificación del archivo (UTF-8 recomendado)",
    "4. Crear consulta previa de validación en Power Query",
    "5. Guardar respaldo del archivo fuente en cada carga crítica",
    "6. Evitar ediciones manuales una vez integrado el flujo"
]

for práctica in prácticas:
    print(f"  ✓ {práctica}")

# %% [markdown]
# ### Trabajar con JSON

# %%
# ── Slide 6: Estructura JSON

# JSON es semiestructurado, típicamente de APIs
json_data = {
    "resultados": [
        {
            "id": 1,
            "cliente": "Empresa A",
            "transacciones": [
                {"fecha": "2024-01-15", "monto": 5000},
                {"fecha": "2024-01-20", "monto": 3500}
            ]
        },
        {
            "id": 2,
            "cliente": "Empresa B",
            "transacciones": [
                {"fecha": "2024-01-18", "monto": 8000}
            ]
        }
    ]
}

print("\n" + "=" * 80)
print("ARCHIVO JSON - Estructura jerárquica")
print("=" * 80)
print(json.dumps(json_data, indent=2)[:500] + "...")

print("\nNota: Power BI requerirá EXPANDIR las estructuras anidadas")
print("Esto se hace en Power Query mediante 'Expandir' en las columnas de listas")

# %% [markdown]
# # PARTE 2: Planillas Excel
#
# ## Slide 12-16: Conectar a Excel

# %% [markdown]
# ### Estructuras comunes en Excel (Slide 13)

# %%
# ── Slide 12-13: Tipos de estructuras Excel

print("\n" + "=" * 80)
print("TIPOS DE ESTRUCTURAS EN EXCEL")
print("=" * 80)

estructuras = {
    "Tablas formateadas": {
        "descripción": "Datos con encabezados claros y formato de tabla",
        "ventaja": "Ideal para Power BI, permite identificación rápida",
        "recomendación": "✓ PREFERIDA en Power BI"
    },
    "Rangos de celdas simples": {
        "descripción": "Datos sin formato de tabla, solo celdas",
        "ventaja": "Simple, pero requiere validación",
        "recomendación": "⚠ Requiere paso de promoción de encabezado"
    },
    "Múltiples hojas": {
        "descripción": "Cada hoja es una estructura de datos diferente",
        "ventaja": "Modular, pero requiere combinación en Power Query",
        "recomendación": "Combinar solo si tienen mismo esquema"
    },
    "Estructuras mixtas": {
        "descripción": "Texto, resúmenes, gráficos, celdas fusionadas",
        "ventaja": "Flexible para usuarios, pero difícil para análisis",
        "recomendación": "✗ EVITAR - Requiere manual en Power Query"
    }
}

for tipo, info in estructuras.items():
    print(f"\n{tipo}")
    print(f"  Descripción: {info['descripción']}")
    print(f"  Ventaja: {info['ventaja']}")
    print(f"  {info['recomendación']}")

# %% [markdown]
# ### Problemas estructurales frecuentes en Excel (Slide 14)

# %%
# ── Slide 14: Errores comunes

print("\n" + "=" * 80)
print("PROBLEMAS ESTRUCTURALES FRECUENTES EN EXCEL")
print("=" * 80)

problemas = {
    "Encabezados mal ubicados": {
        "ejemplo": "Encabezado en fila 5 en lugar de fila 1",
        "solución": "En Power Query: Usar 'Promocionar encabezados' desde fila correcta",
        "severidad": "ALTA"
    },
    "Celdas combinadas": {
        "ejemplo": "Varios títulos combinados que representan una columna",
        "solución": "Deshacer combinación en origen o usar Power Query para rellenar",
        "severidad": "ALTA"
    },
    "Nombres duplicados o vacíos": {
        "ejemplo": "Columnas como 'Column', 'Column1', 'Column1_1'",
        "solución": "Renombrar en Power Query antes de cargar",
        "severidad": "MEDIA"
    },
    "Datos heterogéneos": {
        "ejemplo": "Misma columna con texto y números",
        "solución": "Limpiar en origen o usar transformación tipo en Power Query",
        "severidad": "MEDIA"
    },
    "Formularios incrustados": {
        "ejemplo": "Datos intercalados con resúmenes o totales parciales",
        "solución": "Reestructurar en origen o copiar solo datos limpios",
        "severidad": "ALTA"
    }
}

for problema, detalles in problemas.items():
    print(f"\n⚠ {problema}")
    print(f"    Ejemplo: {detalles['ejemplo']}")
    print(f"    Solución: {detalles['solución']}")
    print(f"    Severidad: {detalles['severidad']}")

# %% [markdown]
# ### Transformaciones esenciales en Excel (Slide 15)

# %%
# ── Slide 15-16: Buenas prácticas

print("\n" + "=" * 80)
print("TRANSFORMACIONES Y BUENAS PRÁCTICAS EN EXCEL")
print("=" * 80)

transformaciones = [
    "1. Promover encabezados desde la fila correcta",
    "2. Eliminar columnas vacías tras importación",
    "3. Separar hojas por contexto de datos",
    "4. Usar nombre dinámico de hoja/tabla",
    "5. Convertir rangos a tablas en el origen"
]

buenas_prácticas = [
    "✓ Solicitar estandarizar encabezados y formatos",
    "✓ Evitar celdas combinadas en datos",
    "✓ Mantener nombres únicos para hojas y columnas",
    "✓ Usar OneDrive/SharePoint para actualización automática",
    "✓ Aplicar validación manual previa a cargas masivas",
    "✓ Documentar claramente pasos en Power Query"
]

print("\nTransformaciones típicas en Power Query:")
for t in transformaciones:
    print(f"  {t}")

print("\nRecomendaciones técnicas:")
for p in buenas_prácticas:
    print(f"  {p}")

# %% [markdown]
# # PARTE 3: Bases de datos
#
# ## Slide 18-23: Conectar a BD Relacionales y NoSQL

# %% [markdown]
# ### Tipos de bases de datos compatibles (Slide 19)

# %%
# ── Slide 18-19: Tipos de BD

print("\n" + "=" * 80)
print("BASES DE DATOS COMPATIBLES CON POWER BI")
print("=" * 80)

bd_relacionales = [
    "Microsoft SQL Server (local y Azure)",
    "PostgreSQL",
    "Oracle Database",
    "MySQL",
    "IBM DB2"
]

bd_nosql = [
    "MongoDB (documental)",
    "Azure Cosmos DB (multimodelo)",
    "Firebase (clave-valor)",
    "Apache Cassandra (columnar)"
]

print("\nBases de datos RELACIONALES (RDBMS):")
for bd in bd_relacionales:
    print(f"  • {bd}")

print("\nBases de datos NO RELACIONALES (NoSQL):")
for bd in bd_nosql:
    print(f"  • {bd}")

# %% [markdown]
# ### Conexión segura y eficiente (Slide 20)

# %%
# ── Slide 20: Aspectos de conexión

print("\n" + "=" * 80)
print("ASPECTOS CLAVE DE CONEXIÓN A BASES DE DATOS")
print("=" * 80)

aspectos = {
    "Autenticación": {
        "opciones": [
            "Windows (integrada)",
            "Usuario/Contraseña",
            "OAuth2",
            "Certificados"
        ],
        "recomendación": "Alinear con políticas de seguridad organizacional"
    },
    "Query Folding": {
        "descripción": "Aplicar filtros en el servidor antes de traer datos",
        "beneficio": "Reduce recursos, mejora velocidad de carga",
        "recomendación": "Usar siempre que sea posible"
    },
    "Indexación y Vistas": {
        "descripción": "Usar tablas indexadas y vistas optimizadas",
        "beneficio": "Mejora rendimiento de consultas",
        "recomendación": "Solicitar al DBA vistas personalizadas"
    },
    "Parámetros dinámicos": {
        "descripción": "Adaptar origen sin modificar flujo completo",
        "beneficio": "Flexibilidad multicliente/multiambiente",
        "recomendación": "Usar en ambientes múltiples (prod, testing)"
    }
}

for aspecto, detalles in aspectos.items():
    print(f"\n{aspecto}:")
    if "opciones" in detalles:
        print(f"  Opciones: {', '.join(detalles['opciones'])}")
    if "descripción" in detalles:
        print(f"  → {detalles['descripción']}")
    if "beneficio" in detalles:
        print(f"  ✓ Beneficio: {detalles['beneficio']}")
    print(f"  💡 {detalles['recomendación']}")

# %% [markdown]
# ### Desafíos técnicos y buenas prácticas (Slide 22-23)

# %%
# ── Slide 22-23: Desafíos y prácticas

print("\n" + "=" * 80)
print("DESAFÍOS Y BUENAS PRÁCTICAS EN CONEXIÓN A BASES DE DATOS")
print("=" * 80)

desafíos = {
    "Accesibilidad y permisos": {
        "problema": "Usuario sin privilegios en tablas requeridas",
        "mitigación": "Coordinar con DBA para asignar roles correctos"
    },
    "Volumen y rendimiento": {
        "problema": "Extraer grandes volúmenes sin filtros ralentiza sistema",
        "mitigación": "Usar query folding, vistas optimizadas, filtros en origen"
    },
    "Cambios estructurales": {
        "problema": "Renombramiento o eliminación de tablas rompe flujo",
        "mitigación": "Documentar estructura, validar cambios con DBA"
    },
    "Concurrencia": {
        "problema": "Bloqueos si múltiples usuarios consultan simultáneamente",
        "mitigación": "Usar vistas, limitar frecuencia actualización"
    }
}

prácticas = [
    "1. Solicitar al DBA vistas personalizadas filtradas/agregadas",
    "2. Documentar cada conexión: origen, auth, frecuencia, propósito",
    "3. Usar parámetros para distinguir entornos (prod vs testing)",
    "4. Verificar políticas de retención de datos",
    "5. Aplicar limitaciones iniciales (TOP N, fechas recientes)"
]

print("\nDesafíos técnicos frecuentes:")
for desafío, detalles in desafíos.items():
    print(f"\n  ⚠ {desafío}")
    print(f"     Problema: {detalles['problema']}")
    print(f"     → {detalles['mitigación']}")

print("\nBuenas prácticas recomendadas:")
for práctica in prácticas:
    print(f"  ✓ {práctica}")

# %% [markdown]
# # PARTE 4: Scripts de Python
#
# ## Slide 25-29: Integración de Python con Power BI

# %% [markdown]
# ### Fundamentos de conexión con Python (Slide 26)

# %%
# ── Slide 26: Script de Python básico para Power BI
# NOTA: Este código será ejecutable en Power BI Desktop

print("\n" + "=" * 80)
print("SCRIPT DE PYTHON PARA POWER BI (Slide 39)")
print("=" * 80)

# Ejemplo del código que aparece en Slide 39:
python_code = '''
import pandas as pd

df = pd.DataFrame({
    'ID': [101, 102, 103],
    'Servicio': ['Soporte', 'Consultoría', 'Implementación'],
    'Satisfacción': [4.5, 3.8, 4.9]
})
'''

print("\nCódigo ejecutado en Power BI:")
print(python_code)

# Ejecutar el código para mostrar resultado
df = pd.DataFrame({
    'ID': [101, 102, 103],
    'Servicio': ['Soporte', 'Consultoría', 'Implementación'],
    'Satisfacción': [4.5, 3.8, 4.9]
})

print("Resultado (DataFrame retornado a Power BI):")
print(df)

# %% [markdown]
# ### Librerías comunes en Python para Power BI (Slide 26)

# %%
# ── Slide 26: Librerías recomendadas

print("\n" + "=" * 80)
print("LIBRERÍAS COMUNES PARA SCRIPTS EN POWER BI")
print("=" * 80)

librerías = {
    "pandas": {
        "uso": "Manipulación de datos estructurados",
        "ejemplo": "df.groupby('Región').sum()",
        "importancia": "★★★★★"
    },
    "numpy": {
        "uso": "Operaciones numéricas avanzadas",
        "ejemplo": "np.mean(), np.std()",
        "importancia": "★★★★☆"
    },
    "re (regex)": {
        "uso": "Expresiones regulares para limpieza de texto",
        "ejemplo": "re.sub(r'[^0-9]', '', texto)",
        "importancia": "★★★★☆"
    },
    "datetime": {
        "uso": "Conversión y tratamiento de fechas",
        "ejemplo": "pd.to_datetime(df['fecha'])",
        "importancia": "★★★★☆"
    },
    "scipy/sklearn": {
        "uso": "Modelos estadísticos y machine learning",
        "ejemplo": "from sklearn import preprocessing",
        "importancia": "★★★☆☆"
    }
}

for librería, detalles in librerías.items():
    print(f"\n{librería} {detalles['importancia']}")
    print(f"  Uso: {detalles['uso']}")
    print(f"  Ejemplo: {detalles['ejemplo']}")

# %% [markdown]
# ### Casos de uso justificados (Slide 27)

# %%
# ── Slide 27: Casos de uso

print("\n" + "=" * 80)
print("CASOS DE USO JUSTIFICADOS PARA SCRIPTS PYTHON")
print("=" * 80)

casos_uso = {
    "Preprocesamiento no estructurado": {
        "situación": "APIs complejas, logs, archivos heterogéneos",
        "solución": "Script que limpia, reestructura antes de cargar",
        "ventaja": "Power Query no tiene capacidad suficiente"
    },
    "Análisis estadístico previo": {
        "situación": "Necesitas desv.std, correlaciones, puntajes Z",
        "solución": "Script con numpy/scipy calcula métricas",
        "ventaja": "Más rápido que construir en Power Query"
    },
    "Transformaciones sofisticadas": {
        "situación": "Pivoteo múltiple, agrupamientos complejos",
        "solución": "Script pandas resuelve en pocas líneas",
        "ventaja": "Menos pasos, más legible"
    },
    "Machine learning integrado": {
        "situación": "Modelo pre-entrenado necesita puntuaciones",
        "solución": "Script aplica modelo, retorna etiquetas",
        "ventaja": "Ciencia de datos directamente en reportes"
    }
}

for caso, detalles in casos_uso.items():
    print(f"\n{caso}")
    print(f"  Situación: {detalles['situación']}")
    print(f"  Solución: {detalles['solución']}")
    print(f"  ✓ {detalles['ventaja']}")

# %% [markdown]
# ### Configuración y buenas prácticas (Slide 28-29)

# %%
# ── Slide 28-29: Configuración y buenas prácticas

print("\n" + "=" * 80)
print("CONFIGURACIÓN Y BUENAS PRÁCTICAS PARA PYTHON EN POWER BI")
print("=" * 80)

configuración = [
    "1. Instalar distribución Python compatible (Anaconda o Python 3.9+)",
    "2. Establecer intérprete en Power BI: Archivo > Opciones > Scripts de Python",
    "3. Instalar librerías requeridas: pip install pandas numpy scikit-learn",
    "4. Usar entornos virtuales para control de versiones"
]

recomendaciones = [
    "✓ Utilizar entornos virtuales (venv, conda)",
    "✓ Verificar reproducibilidad en cualquier equipo",
    "✓ Limitar lógica compleja: solo lo necesario en Python",
    "✓ Probar script fuera de Power BI primero",
    "✓ Documentar claramente propósito de cada paso"
]

errores_frecuentes = [
    "✗ Asumir que scripts funcionarán en Power BI Service (solo Desktop)",
    "✗ No validar tipo de datos del DataFrame retornado",
    "✗ Embutir lógica sensible sin auditoría",
    "✗ No documentar el código",
    "✗ Usar credenciales hardcodeadas en scripts"
]

print("\nPasos de configuración:")
for paso in configuración:
    print(f"  {paso}")

print("\nRecomendaciones clave:")
for rec in recomendaciones:
    print(f"  {rec}")

print("\nErrores comunes a EVITAR:")
for error in errores_frecuentes:
    print(f"  {error}")

# %% [markdown]
# # PARTE 5: Otras fuentes de datos
#
# ## Slide 31-35: Cloud, APIs, carpetas, servicios

# %%
# ── Slide 31-35: Otras fuentes

print("\n" + "=" * 80)
print("OTRAS FUENTES DE DATOS EN POWER BI")
print("=" * 80)

otras_fuentes = {
    "SharePoint / OneDrive": {
        "características": [
            "Conexión a archivos hospedados",
            "Actualización automática desde Web",
            "Integración con Microsoft 365"
        ],
        "desafío": "Usar rutas correctas (no URLs de navegador)",
        "ventaja": "Trazabilidad, actualización automática"
    },
    "APIs REST": {
        "características": [
            "Datos en JSON/XML desde endpoints",
            "Autenticación con tokens/keys",
            "Paginación para datasets completos"
        ],
        "desafío": "Manejar paginación, headers, timeouts",
        "ventaja": "Datos en tiempo real, flexible"
    },
    "Carpetas organizadas": {
        "características": [
            "Combinación automática de archivos similares",
            "Estructura homogénea esperada",
            "Transformación replicada a todos"
        ],
        "desafío": "Cambios estructurales rompen proceso",
        "ventaja": "Automatiza cargas periódicas"
    },
    "Cloud Storage (S3, Azure, GCS)": {
        "características": [
            "Archivos en contenedores cloud",
            "Autenticación con credenciales",
            "Escalable, económico"
        ],
        "desafío": "Manejar claves, latencia, cuotas",
        "ventaja": "Infraestructura moderna, segura"
    }
}

for fuente, detalles in otras_fuentes.items():
    print(f"\n{fuente}")
    print(f"  Características:")
    for caract in detalles['características']:
        print(f"    • {caract}")
    print(f"  ⚠ Desafío: {detalles['desafío']}")
    print(f"  ✓ Ventaja: {detalles['ventaja']}")

# %% [markdown]
# # PARTE 6: Ejercicio práctico
#
# ## Slide 37-40: Integración múltiple de fuentes

# %% [markdown]
# ### Tabla comparativa de fuentes (Slide 40)

# %%
# ── Slide 40: Tabla comparativa

import pandas as pd

tabla_comparativa = pd.DataFrame({
    'Tipo de fuente': ['CSV', 'Excel', 'Base de datos', 'Script de Python'],
    'Ventajas principales': [
        'Simpleza, bajo peso, integraciones automáticas',
        'Accesibilidad generalizada, soporte tablas dinámicas',
        'Escalabilidad, integridad, control centralizado',
        'Lógica compleja, transformaciones sofisticadas, ML integrado'
    ],
    'Riesgos o desafíos': [
        'Falta validación, errores manuales frecuentes',
        'Variabilidad estructural, cambios manuales',
        'Complejidad técnica, permisos, volumen',
        'Dependencia local, mantenimiento, documentación'
    ],
    'Recomendaciones clave': [
        'Carpeta controlada, estructura fija, UTF-8',
        'Estandarizar formato, evitar celdas combinadas',
        'Vistas del DBA, parámetros dinámicos, documentar',
        'Entorno virtual, probar fuera PBI, documentar bien'
    ]
})

print("\n" + "=" * 80)
print("TABLA COMPARATIVA DE FUENTES DE DATOS")
print("=" * 80)
print(tabla_comparativa.to_string(index=False))

# %% [markdown]
# # RESUMEN Y CONCLUSIONES
#
# ## Slide 41: Resumen de conceptos clave

# %%
# ── Slide 41: Resumen

print("\n" + "=" * 80)
print("RESUMEN - OPCIONES DE CONEXIÓN A FUENTES DE DATOS EN POWER BI")
print("=" * 80)

resumen_puntos = [
    "1. Comprendimos fundamentos técnicos de distintos mecanismos de conexión",
    "2. Diferenciamos características, ventajas y limitaciones de cada método",
    "3. Analizamos escenarios prácticos para aplicar cada tipo de conexión",
    "4. Identificamos riesgos comunes (duplicidad, actualizaciones, rendimiento)",
    "5. Establecimos criterios para seleccionar mecanismo más adecuado"
]

print("\nLecciones clave:")
for punto in resumen_puntos:
    print(f"  {punto}")

print("\n" + "=" * 80)
print("PREGUNTA DE REFLEXIÓN (Slide 42)")
print("=" * 80)
print("""
¿Cómo influye la elección del mecanismo de conexión 
en el rendimiento del informe y su mantenibilidad?

Respuesta: 
- Importación: Rápida, pero datos estáticos, requiere actualización
- DirectQuery: Datos dinámicos, pero query-dependent, puede ser lenta
- Live Connection: Tiempo real, pero simple, menos control
- Composite: Flexible, pero compleja de mantener
""")
